# %% [markdown]
# ## 2025/8/20
# 1. 日本公布贸易帐（未季调）<br />
#   今值-117.5B	预计196.2B	前值152.1B，出口量依旧不及预期，表现为TOPIX、日经微下调。（想买的Nintendo、スシロー还是太贵了……）

# %% [markdown]
# ## 2025/8/21
# 日经继续小幅下调。<br />
# 看下sushiro(3563.T)、Nintendo(7974.T)的交易量。<br />

# %%
import yfinance as yf
# 自动重新加载类
# %load_ext autoreload
# %autoreload 2
# class是关键字 切忌不能用来命名
from src.classes.technical_analysis import TechnicalAnalysis
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# C:\Users\yuting.d.zhang\AppData\Local\Temp\ipykernel_34968\655808140.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_nintendo = yf.download(["7974.T"], period="1y", interval="1d")
# [*********************100%***********************]  1 of 1 completed
#                    Close          High           Low          Open   Volume
# Date
# 2024-08-27   7951.023926   7955.963677   7827.530140   7854.204797  2630700
# 2024-08-28   7870.999512   7912.493422   7812.710448   7854.204358  2242000
# 2024-08-29   7775.168945   7862.108573   7775.168945   7834.445964  2957500
# 2024-08-30   7806.783203   7834.445811   7766.277241   7766.277241  3566200
# 2024-09-02   7827.529785   7882.854999   7815.674382   7861.120093  1965200
# ...                  ...           ...           ...           ...      ...
# 2025-08-21  13685.000000  13820.000000  13605.000000  13805.000000  3086100
# 2025-08-22  13760.000000  13890.000000  13725.000000  13800.000000  2893600
# 2025-08-25  13750.000000  13935.000000  13670.000000  13890.000000  3436600
# 2025-08-26  13525.000000  13750.000000  13525.000000  13660.000000  3348200
# 2025-08-27  13390.000000  13470.000000  13210.000000  13400.000000  2568500
#
# [245 rows x 5 columns]

# %%
df_sushiro = yf.download(["3563.T"], period="1y", interval="1d")
df_sushiro.columns = ["Close","High","Low","Open","Volume"]
TechnicalAnalysis(df_sushiro).plot_volume()
# Out:
# C:\Users\yuting.d.zhang\AppData\Local\Temp\ipykernel_34968\3333121629.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_sushiro = yf.download(["3563.T"], period="1y", interval="1d")
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# 1. 2025/5/9 在决算期后大量交易、收盘价5750合适。<br />
# 2. 2025/8/6 在决算期后大量交易、收盘价7713合适。<br />
# 3. 一个财报周期一次大交易。<br />
#
# 餐饮行业估值困难、好方法就是定投股票。等放财报、大波动时期交易一波<br />
